# %% [markdown]
# # Business Understanding
#
# ## Project Overview
#
# This project investigates residential property prices in Ames, Iowa using the Heritage Housing dataset. The aim is to understand which property characteristics have the greatest influence on house sale prices and to develop a machine learning model capable of predicting the sale price of a property based on its attributes.
#
# The project follows the CRISP-DM methodology, beginning with business understanding before progressing through data exploration, data preparation, modelling, evaluation, and deployment.
#
# ## Objectives
#
# The objectives of this notebook are to:
#
# - Understand the client's business problem and business requirements.
# - Become familiar with the Heritage Housing dataset.
# - Define hypotheses that can be tested through data analysis.
# - Plan an analytical approach capable of answering the client's questions.
# - Establish the foundation for the remaining stages of the CRISP-DM process.
#
# ---
#
# ## Inputs
#
# This notebook uses the following inputs:
#
# - Heritage Housing dataset supplied by Code Institute.
# - Business requirements provided by the client.
# - Background information describing the inherited properties.
#
# ---
#
# ## Outputs
#
# At the end of this notebook the following outputs are produced:
#
# - Clearly defined business requirements
# - Initial project hypotheses
# - Understanding of the analytical workflow
# - Initial inspection of the housing dataset.

# %% [markdown]
# ## Business Requirements
#
# The client inherited four residential properties located in Ames, Iowa and would like support in estimating their market value. Because the client is unfamiliar with the local housing market, historical housing data will be analysed to identify the characteristics that most strongly influence sale prices.
#
# The project aims to satisfy the following business requirements:
#
# 1. Identify which house attributes have the strongest relationship with sale price.
# 2. Visualise the most influential variables to better understand their impact.
# 3. Predict the sale prices of four inherited houses.
# 4. Provide a tool that can estimate the sale price of any house in Ames, Iowa.

# %%
import pandas as pd

df = pd.read_csv("../inputs/datasets/house_prices_records.csv")

# %% [markdown]
# ## Dataset Overview
#
# The Heritage Housing dataset contains historical residential property sales from Ames, Iowa. Before beginning exploratory data analysis, the dataset is inspected to understand its structure, size, available variables, and data types.
#
# This initial inspection helps identify the information available for modelling and highlights any issues that may require cleaning during later stages of the project.

# %%
df.head()
# Out:
#    1stFlrSF  2ndFlrSF  BedroomAbvGr BsmtExposure  BsmtFinSF1 BsmtFinType1  \
# 0       856     854.0           3.0           No         706          GLQ
# 1      1262       0.0           3.0           Gd         978          ALQ
# 2       920     866.0           3.0           Mn         486          GLQ
# 3       961       NaN           NaN           No         216          ALQ
# 4      1145       NaN           4.0           Av         655          GLQ
#
#    BsmtUnfSF  EnclosedPorch  GarageArea GarageFinish  ...  LotFrontage  \
# 0        150            0.0         548          RFn  ...         65.0
# 1        284            NaN         460          RFn  ...         80.0
# 2        434            0.0         608          RFn  ...         68.0
# 3        540            NaN         642          Unf  ...         60.0
# 4        490            0.0         836          RFn  ...         84.0
#
#    MasVnrArea OpenPorchSF  OverallCond  OverallQual  TotalBsmtSF  WoodDeckSF  \
# ...

# %% [markdown]
# ### Dataset Shape
#
# The shape of the dataset is examined to determine the number of observations and variables available for analysis.

# %%
df.shape
# Out:
# (1460, 24)

# %% [markdown]
# ### Dataset Information
#
# The dataset information is inspected to review variable types and identify any obvious missing values that may require preprocessing later in the project.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   1stFlrSF       1460 non-null   int64
#  1   2ndFlrSF       1374 non-null   float64
#  2   BedroomAbvGr   1361 non-null   float64
#  3   BsmtExposure   1422 non-null   object
#  4   BsmtFinSF1     1460 non-null   int64
#  5   BsmtFinType1   1315 non-null   object
#  6   BsmtUnfSF      1460 non-null   int64
#  7   EnclosedPorch  136 non-null    float64
#  8   GarageArea     1460 non-null   int64
#  9   GarageFinish   1225 non-null   object
#  10  GarageYrBlt    1379 non-null   float64
#  11  GrLivArea      1460 non-null   int64
#  12  KitchenQual    1460 non-null   object
#  13  LotArea        1460 non-null   int64
#  14  LotFrontage    1201 non-null   float64
#  15  MasVnrArea     1452 non-null   float64
#  16  OpenPorchSF    1460 non-null   int64
# ...

# %% [markdown]
# ## Project Hypotheses
#
# Before exploring the dataset, several hypotheses were established based on domain knowledge and the client's business objectives. These hypotheses will be investigated during the exploratory data analysis and model development stages.
#
# The hypotheses are:
#
# 1. Houses with higher overall quality are expected to achieve higher sale prices.
# 2. Larger living areas are expected to increase house prices.
# 3. Newer houses are expected to sell for higher prices than older houses.
# 4. Houses with garages are expected to have higher sale prices.
# 5. The selected property features are expected to provide sufficient information to build a reliable house price prediction model.
